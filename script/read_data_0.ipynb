# %%
import pandas as pd
import numpy as np
import datetime, warnings, scipy
import seaborn as sns

# %%
df1 = pd.read_csv(filepath_or_buffer = '../data/2008.csv')

# %%
df1.loc[:, "CRSDepTime"]
# Out:
# 0          1955
# 1           735
# 2           620
# 3           930
# 4          1755
# 5          1915
# 6          1830
# 7          1040
# 8           615
# 9          1620
# 10          700
# 11         1510
# 12         1430
# 13          715
# 14         1700
# 15         1020
# 16         1425
# 17          745
# 18         1255
# 19         1325
# 20          705
# 21         1625
# 22         1840
# 23         1030
# 24          800
# 25         1455
# 26         1255
# 27         1925
# 28          635
# 29          730
#            ...
# 7009698    1635
# 7009699    1221
# 7009700    1845
# 7009701    1500
# 7009702    1522
# 7009703    1910
# 7009704    1445
# 7009705     830
# 7009706    1440
# 7009707    1755
# 7009708     710
# 7009709    1520
# 7009710    1220
# 7009711    1041
# 7009712     843
# 7009713     815
# 7009714     545
# 7009715     850
# 7009716     936
# 7009717     600
# 7009718     847
# 7009719     640
# 7009720     800
# 7009721     615
# ...

# %%
#Convert the HHMM format to HH:MM format
def format_hour(hm):
    if pd.isnull(hm):
        return np.nan
    else:
        if hm == 2400: hm = 0
        hm = "{0:04d}".format(int(hm))
        newHM = datetime.time(int(hm[0:2]), int(hm[2:4]))
        return newHM

# %%
df1['CRSDepTime'] = df1['CRSDepTime'].apply(format_hour)

# %%
df1['CRSDepTime']
# Out:
# 0          19:55:00
# 1          07:35:00
# 2          06:20:00
# 3          09:30:00
# 4          17:55:00
# 5          19:15:00
# 6          18:30:00
# 7          10:40:00
# 8          06:15:00
# 9          16:20:00
# 10         07:00:00
# 11         15:10:00
# 12         14:30:00
# 13         07:15:00
# 14         17:00:00
# 15         10:20:00
# 16         14:25:00
# 17         07:45:00
# 18         12:55:00
# 19         13:25:00
# 20         07:05:00
# 21         16:25:00
# 22         18:40:00
# 23         10:30:00
# 24         08:00:00
# 25         14:55:00
# 26         12:55:00
# 27         19:25:00
# 28         06:35:00
# 29         07:30:00
#              ...
# 7009698    16:35:00
# 7009699    12:21:00
# 7009700    18:45:00
# 7009701    15:00:00
# 7009702    15:22:00
# 7009703    19:10:00
# 7009704    14:45:00
# 7009705    08:30:00
# 7009706    14:40:00
# 7009707    17:55:00
# 7009708    07:10:00
# 7009709    15:20:00
# 7009710    12:20:00
# 7009711    10:41:00
# ...

# %% [markdown]
# Apply the same formart for Arrival Time

# %%
df1.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  7009728.0  7.009728e+06  7.009728e+06  7.009728e+06  6.873482e+06
# mean      2008.0  6.375130e+00  1.572801e+01  3.924182e+00  1.333830e+03
# std          0.0  3.406737e+00  8.797068e+00  1.988259e+00  4.780689e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  9.280000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.325000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.728000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#             ArrTime    CRSArrTime     FlightNum  ActualElapsedTime  \
# count  6.858079e+06  7.009728e+06  7.009728e+06       6.855029e+06
# mean   1.481258e+03  1.494801e+03  2.224200e+03       1.273224e+02
# std    5.052251e+02  4.826728e+02  1.961716e+03       7.018731e+01
# ...

# %%
df1['CRSArrTime'] = df1['CRSArrTime'].apply(format_hour)
df1['CRSArrTime']
# Out:
# 0          22:25:00
# 1          10:00:00
# 2          07:50:00
# 3          11:00:00
# 4          19:25:00
# 5          21:10:00
# 6          19:40:00
# 7          11:50:00
# 8          06:50:00
# 9          16:55:00
# 10         09:15:00
# 11         17:25:00
# 12         14:25:00
# 13         07:10:00
# 14         16:55:00
# 15         10:10:00
# 16         16:25:00
# 17         09:55:00
# 18         15:10:00
# 19         14:35:00
# 20         08:10:00
# 21         17:35:00
# 22         19:50:00
# 23         11:40:00
# 24         09:10:00
# 25         16:05:00
# 26         16:10:00
# 27         22:35:00
# 28         09:45:00
# 29         10:20:00
#              ...
# 7009698    17:58:00
# 7009699    13:59:00
# 7009700    20:06:00
# 7009701    16:42:00
# 7009702    18:23:00
# 7009703    20:16:00
# 7009704    16:22:00
# 7009705    10:08:00
# 7009706    17:04:00
# 7009707    20:15:00
# 7009708    08:37:00
# 7009709    17:18:00
# 7009710    15:52:00
# 7009711    13:03:00
# ...

# %% [markdown]
# ## Putting Departure Time and Arrival Time togerther

# %%
df1.loc[:, ['CRSDepTime', 'CRSArrTime']]
# Out:
#         CRSDepTime CRSArrTime
# 0         19:55:00   22:25:00
# 1         07:35:00   10:00:00
# 2         06:20:00   07:50:00
# 3         09:30:00   11:00:00
# 4         17:55:00   19:25:00
# 5         19:15:00   21:10:00
# 6         18:30:00   19:40:00
# 7         10:40:00   11:50:00
# 8         06:15:00   06:50:00
# 9         16:20:00   16:55:00
# 10        07:00:00   09:15:00
# 11        15:10:00   17:25:00
# 12        14:30:00   14:25:00
# 13        07:15:00   07:10:00
# 14        17:00:00   16:55:00
# 15        10:20:00   10:10:00
# 16        14:25:00   16:25:00
# 17        07:45:00   09:55:00
# 18        12:55:00   15:10:00
# 19        13:25:00   14:35:00
# 20        07:05:00   08:10:00
# 21        16:25:00   17:35:00
# 22        18:40:00   19:50:00
# 23        10:30:00   11:40:00
# 24        08:00:00   09:10:00
# 25        14:55:00   16:05:00
# 26        12:55:00   16:10:00
# 27        19:25:00   22:35:00
# 28        06:35:00   09:45:00
# 29        07:30:00   10:20:00
# ...
